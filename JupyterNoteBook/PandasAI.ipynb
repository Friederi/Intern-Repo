# %% [markdown]
# ## PandasAI

# %%
import pandas as pd
import pandasai as pai
from pandasai import SmartDataframe

pai.api_key.set("PAI-e6e0a370-8017-4081-bb46-3589b936a2b3")


df = pd.read_csv("data/input_search_DB.csv", encoding="utf-8", keep_default_na=False)

smart_df = SmartDataframe(df)

question = 'Please list all data that are nearly similiar to the input "{本文1}" '

answer = smart_df.chat(question)

print(answer)
# Out:
# C:\Users\hvuongbaovo\AppData\Local\Temp\ipykernel_28204\62990709.py:10: DeprecationWarning:
# ********************************************************************************
# DEPRECATION WARNING:
# SmartDataframe will soon be deprecated. Please use df.chat() instead.
# ********************************************************************************
#
#   smart_df = SmartDataframe(df)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\hvuongbaovo\AppData\Local\Programs\Python\Python311\Lib\logging\__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "C:\Users\hvuongbaovo\AppData\Local\Programs\Python\Python311\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 98-99: character maps to <undefined>
# Call stack:
# ...
